# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv('googleplaystore.csv')

# %%
dataset.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
dataset.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
dataset.shape
# Out:
# (10841, 13)

# %%
dataset.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data = dataset.dropna()

# %%
data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10834     4.0       7                2.6M         500+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10834       Everyone                  Education     June 18, 2017
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10834               1.0.0          4.1 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [9360 rows x 13 columns]

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#       index                                                App  \
# 0         0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1                                Coloring book moana
# 2         2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3                              Sketch - Draw & Paint
# 4         4              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 9355  10834                                      FR Calculator
# 9356  10836                                   Sya9a Maroc - FR
# 9357  10837                   Fr. Mike Schmitz Audio Teachings
# 9358  10839                      The SCP Foundation DB fr nn5n
# 9359  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating Reviews                Size     Installs  \
# 0          ART_AND_DESIGN     4.1     159                 19M      10,000+
# 1          ART_AND_DESIGN     3.9     967                 14M     500,000+
# 2          ART_AND_DESIGN     4.7   87510                8.7M   5,000,000+
# 3          ART_AND_DESIGN     4.5  215644                 25M  50,000,000+
# 4          ART_AND_DESIGN     4.3     967                2.8M     100,000+
# ...                   ...     ...     ...                 ...          ...
# 9355               FAMILY     4.0       7                2.6M         500+
# 9356               FAMILY     4.5      38                 53M       5,000+
# 9357               FAMILY     5.0       4                3.6M         100+
# 9358  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+
# 9359            LIFESTYLE     4.5  398307                 19M  10,000,000+
#
#       Type Price Content Rating                     Genres      Last Updated  \
# 0     Free     0       Everyone               Art & Design   January 7, 2018
# 1     Free     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     Free     0       Everyone               Art & Design    August 1, 2018
# 3     Free     0           Teen               Art & Design      June 8, 2018
# 4     Free     0       Everyone    Art & Design;Creativity     June 20, 2018
# ...    ...   ...            ...                        ...               ...
# 9355  Free     0       Everyone                  Education     June 18, 2017
# 9356  Free     0       Everyone                  Education     July 25, 2017
# 9357  Free     0       Everyone                  Education      July 6, 2018
# 9358  Free     0     Mature 17+          Books & Reference  January 19, 2015
# 9359  Free     0       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9355               1.0.0          4.1 and up
# 9356                1.48          4.1 and up
# 9357                 1.0          4.1 and up
# 9358  Varies with device  Varies with device
# 9359  Varies with device  Varies with device
#
# [9360 rows x 14 columns]

# %%
data = data[data['Size'].str.contains('Varies with device') == False]
data
# Out:
#       index                                                App  \
# 0         0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1                                Coloring book moana
# 2         2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3                              Sketch - Draw & Paint
# 4         4              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 9354  10833                                        Chemin (fr)
# 9355  10834                                      FR Calculator
# 9356  10836                                   Sya9a Maroc - FR
# 9357  10837                   Fr. Mike Schmitz Audio Teachings
# 9359  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating Reviews  Size     Installs  Type Price  \
# 0          ART_AND_DESIGN     4.1     159   19M      10,000+  Free     0
# 1          ART_AND_DESIGN     3.9     967   14M     500,000+  Free     0
# 2          ART_AND_DESIGN     4.7   87510  8.7M   5,000,000+  Free     0
# 3          ART_AND_DESIGN     4.5  215644   25M  50,000,000+  Free     0
# 4          ART_AND_DESIGN     4.3     967  2.8M     100,000+  Free     0
# ...                   ...     ...     ...   ...          ...   ...   ...
# 9354  BOOKS_AND_REFERENCE     4.8      44  619k       1,000+  Free     0
# 9355               FAMILY     4.0       7  2.6M         500+  Free     0
# 9356               FAMILY     4.5      38   53M       5,000+  Free     0
# 9357               FAMILY     5.0       4  3.6M         100+  Free     0
# 9359            LIFESTYLE     4.5  398307   19M  10,000,000+  Free     0
#
#      Content Rating                     Genres      Last Updated  \
# 0          Everyone               Art & Design   January 7, 2018
# 1          Everyone  Art & Design;Pretend Play  January 15, 2018
# 2          Everyone               Art & Design    August 1, 2018
# 3              Teen               Art & Design      June 8, 2018
# 4          Everyone    Art & Design;Creativity     June 20, 2018
# ...             ...                        ...               ...
# 9354       Everyone          Books & Reference    March 23, 2014
# 9355       Everyone                  Education     June 18, 2017
# 9356       Everyone                  Education     July 25, 2017
# 9357       Everyone                  Education      July 6, 2018
# 9359       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9354                 0.8          2.2 and up
# 9355               1.0.0          4.1 and up
# 9356                1.48          4.1 and up
# 9357                 1.0          4.1 and up
# 9359  Varies with device  Varies with device
#
# [7723 rows x 14 columns]

# %%
data_M = data[data['Size'].str.contains('M')]
data_M
# Out:
#       index                                                App  \
# 0         0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1                                Coloring book moana
# 2         2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3                              Sketch - Draw & Paint
# 4         4              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 9352  10830                                  News Minecraft.fr
# 9355  10834                                      FR Calculator
# 9356  10836                                   Sya9a Maroc - FR
# 9357  10837                   Fr. Mike Schmitz Audio Teachings
# 9359  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                 Category  Rating Reviews  Size     Installs  Type Price  \
# 0         ART_AND_DESIGN     4.1     159   19M      10,000+  Free     0
# 1         ART_AND_DESIGN     3.9     967   14M     500,000+  Free     0
# 2         ART_AND_DESIGN     4.7   87510  8.7M   5,000,000+  Free     0
# 3         ART_AND_DESIGN     4.5  215644   25M  50,000,000+  Free     0
# 4         ART_AND_DESIGN     4.3     967  2.8M     100,000+  Free     0
# ...                  ...     ...     ...   ...          ...   ...   ...
# 9352  NEWS_AND_MAGAZINES     3.8     881  2.3M     100,000+  Free     0
# 9355              FAMILY     4.0       7  2.6M         500+  Free     0
# 9356              FAMILY     4.5      38   53M       5,000+  Free     0
# 9357              FAMILY     5.0       4  3.6M         100+  Free     0
# 9359           LIFESTYLE     4.5  398307   19M  10,000,000+  Free     0
#
#      Content Rating                     Genres      Last Updated  \
# 0          Everyone               Art & Design   January 7, 2018
# 1          Everyone  Art & Design;Pretend Play  January 15, 2018
# 2          Everyone               Art & Design    August 1, 2018
# 3              Teen               Art & Design      June 8, 2018
# 4          Everyone    Art & Design;Creativity     June 20, 2018
# ...             ...                        ...               ...
# 9352       Everyone           News & Magazines  January 20, 2014
# 9355       Everyone                  Education     June 18, 2017
# 9356       Everyone                  Education     July 25, 2017
# 9357       Everyone                  Education      July 6, 2018
# 9359       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9352                 1.5          1.6 and up
# 9355               1.0.0          4.1 and up
# 9356                1.48          4.1 and up
# 9357                 1.0          4.1 and up
# 9359  Varies with device  Varies with device
#
# [7466 rows x 14 columns]

# %%
data_M['Size'] = data_M['Size'].str.extract('(\d+)')
data_M
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       index                                                App  \
# 0         0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1                                Coloring book moana
# 2         2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3                              Sketch - Draw & Paint
# 4         4              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 9352  10830                                  News Minecraft.fr
# 9355  10834                                      FR Calculator
# 9356  10836                                   Sya9a Maroc - FR
# 9357  10837                   Fr. Mike Schmitz Audio Teachings
# 9359  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                 Category  Rating Reviews Size     Installs  Type Price  \
# 0         ART_AND_DESIGN     4.1     159   19      10,000+  Free     0
# 1         ART_AND_DESIGN     3.9     967   14     500,000+  Free     0
# 2         ART_AND_DESIGN     4.7   87510    8   5,000,000+  Free     0
# 3         ART_AND_DESIGN     4.5  215644   25  50,000,000+  Free     0
# 4         ART_AND_DESIGN     4.3     967    2     100,000+  Free     0
# ...                  ...     ...     ...  ...          ...   ...   ...
# 9352  NEWS_AND_MAGAZINES     3.8     881    2     100,000+  Free     0
# 9355              FAMILY     4.0       7    2         500+  Free     0
# 9356              FAMILY     4.5      38   53       5,000+  Free     0
# 9357              FAMILY     5.0       4    3         100+  Free     0
# 9359           LIFESTYLE     4.5  398307   19  10,000,000+  Free     0
#
#      Content Rating                     Genres      Last Updated  \
# 0          Everyone               Art & Design   January 7, 2018
# 1          Everyone  Art & Design;Pretend Play  January 15, 2018
# 2          Everyone               Art & Design    August 1, 2018
# 3              Teen               Art & Design      June 8, 2018
# 4          Everyone    Art & Design;Creativity     June 20, 2018
# ...             ...                        ...               ...
# 9352       Everyone           News & Magazines  January 20, 2014
# 9355       Everyone                  Education     June 18, 2017
# 9356       Everyone                  Education     July 25, 2017
# 9357       Everyone                  Education      July 6, 2018
# 9359       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9352                 1.5          1.6 and up
# 9355               1.0.0          4.1 and up
# 9356                1.48          4.1 and up
# 9357                 1.0          4.1 and up
# 9359  Varies with device  Varies with device
#
# [7466 rows x 14 columns]

# %%
data_M['Size'] = data_M['Size'].astype(int)
data_M['Size'] = 1000*data_M['Size']
data_M
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       index                                                App  \
# 0         0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1                                Coloring book moana
# 2         2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3                              Sketch - Draw & Paint
# 4         4              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 9352  10830                                  News Minecraft.fr
# 9355  10834                                      FR Calculator
# 9356  10836                                   Sya9a Maroc - FR
# 9357  10837                   Fr. Mike Schmitz Audio Teachings
# 9359  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                 Category  Rating Reviews   Size     Installs  Type Price  \
# 0         ART_AND_DESIGN     4.1     159  19000      10,000+  Free     0
# 1         ART_AND_DESIGN     3.9     967  14000     500,000+  Free     0
# 2         ART_AND_DESIGN     4.7   87510   8000   5,000,000+  Free     0
# 3         ART_AND_DESIGN     4.5  215644  25000  50,000,000+  Free     0
# 4         ART_AND_DESIGN     4.3     967   2000     100,000+  Free     0
# ...                  ...     ...     ...    ...          ...   ...   ...
# 9352  NEWS_AND_MAGAZINES     3.8     881   2000     100,000+  Free     0
# 9355              FAMILY     4.0       7   2000         500+  Free     0
# 9356              FAMILY     4.5      38  53000       5,000+  Free     0
# 9357              FAMILY     5.0       4   3000         100+  Free     0
# 9359           LIFESTYLE     4.5  398307  19000  10,000,000+  Free     0
#
#      Content Rating                     Genres      Last Updated  \
# 0          Everyone               Art & Design   January 7, 2018
# 1          Everyone  Art & Design;Pretend Play  January 15, 2018
# 2          Everyone               Art & Design    August 1, 2018
# 3              Teen               Art & Design      June 8, 2018
# 4          Everyone    Art & Design;Creativity     June 20, 2018
# ...             ...                        ...               ...
# 9352       Everyone           News & Magazines  January 20, 2014
# 9355       Everyone                  Education     June 18, 2017
# 9356       Everyone                  Education     July 25, 2017
# 9357       Everyone                  Education      July 6, 2018
# 9359       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9352                 1.5          1.6 and up
# 9355               1.0.0          4.1 and up
# 9356                1.48          4.1 and up
# 9357                 1.0          4.1 and up
# 9359  Varies with device  Varies with device
#
# [7466 rows x 14 columns]

# %%
data_M.dtypes
# Out:
# index               int64
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size                int64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_k = data[data['Size'].str.contains('k')]
data_k['Size'] = data_k['Size'].str.extract('(\d+)')
data_k['Size'] = data_k['Size'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_k
# Out:
#       index                            App             Category  Rating  \
# 56       58              Restart Navigator    AUTO_AND_VEHICLES     4.0
# 198     209                Plugin:AOT v5.0             BUSINESS     3.1
# 371     384  Hangouts Dialer - Call Phones        COMMUNICATION     4.0
# 437     450                    Caller ID +        COMMUNICATION     4.0
# 445     458                    GO Notifier        COMMUNICATION     4.2
# ...     ...                            ...                  ...     ...
# 9286  10732             Draw with FP sDraw                TOOLS     4.3
# 9301  10755                 Hondata Mobile  MAPS_AND_NAVIGATION     4.3
# 9306  10763            FP Разбитый дисплей               FAMILY     4.5
# 9353  10832                       FR Tides              WEATHER     3.8
# 9354  10833                    Chemin (fr)  BOOKS_AND_REFERENCE     4.8
#
#      Reviews  Size     Installs  Type Price Content Rating             Genres  \
# 56      1403   201     100,000+  Free     0       Everyone    Auto & Vehicles
# 198     4034    23     100,000+  Free     0       Everyone           Business
# 371   122498    79  10,000,000+  Free     0       Everyone      Communication
# 437     9498   118   1,000,000+  Free     0       Everyone      Communication
# 445   124346   695  10,000,000+  Free     0       Everyone      Communication
# ...      ...   ...          ...   ...   ...            ...                ...
# 9286    3268   467     100,000+  Free     0       Everyone              Tools
# 9301     334   676      10,000+  Free     0       Everyone  Maps & Navigation
# 9306     922   552      50,000+  Free     0       Everyone      Entertainment
# 9353    1195   582     100,000+  Free     0       Everyone            Weather
# 9354      44   619       1,000+  Free     0       Everyone  Books & Reference
#
#             Last Updated           Current Ver   Android Ver
# 56       August 26, 2014                 1.0.1    2.2 and up
# 198   September 11, 2015  3.0.1.11 (Build 311)    2.2 and up
# 371    September 2, 2015         0.1.100944346  4.0.3 and up
# 437         June 7, 2016                5.28.0    2.3 and up
# 445         July 6, 2014                   2.8    2.0 and up
# ...                  ...                   ...           ...
# 9286   December 16, 2017                   6.6    2.0 and up
# 9301     August 23, 2016                   1.3  2.3.3 and up
# 9306  September 20, 2014                   1.1    1.6 and up
# 9353   February 16, 2014                   6.0    2.1 and up
# 9354      March 23, 2014                   0.8    2.2 and up
#
# [257 rows x 14 columns]

# %%
new_data = pd.concat([data_M,data_k])
new_data = new_data.reset_index()
new_data
# Out:
#       level_0  index                                                App  \
# 0           0      0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1      1                                Coloring book moana
# 2           2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3      3                              Sketch - Draw & Paint
# 4           4      4              Pixel Draw - Number Art Coloring Book
# ...       ...    ...                                                ...
# 7718     9286  10732                                 Draw with FP sDraw
# 7719     9301  10755                                     Hondata Mobile
# 7720     9306  10763                                FP Разбитый дисплей
# 7721     9353  10832                                           FR Tides
# 7722     9354  10833                                        Chemin (fr)
#
#                  Category  Rating Reviews   Size     Installs  Type Price  \
# 0          ART_AND_DESIGN     4.1     159  19000      10,000+  Free     0
# 1          ART_AND_DESIGN     3.9     967  14000     500,000+  Free     0
# 2          ART_AND_DESIGN     4.7   87510   8000   5,000,000+  Free     0
# 3          ART_AND_DESIGN     4.5  215644  25000  50,000,000+  Free     0
# 4          ART_AND_DESIGN     4.3     967   2000     100,000+  Free     0
# ...                   ...     ...     ...    ...          ...   ...   ...
# 7718                TOOLS     4.3    3268    467     100,000+  Free     0
# 7719  MAPS_AND_NAVIGATION     4.3     334    676      10,000+  Free     0
# 7720               FAMILY     4.5     922    552      50,000+  Free     0
# 7721              WEATHER     3.8    1195    582     100,000+  Free     0
# 7722  BOOKS_AND_REFERENCE     4.8      44    619       1,000+  Free     0
#
#      Content Rating                     Genres        Last Updated  \
# 0          Everyone               Art & Design     January 7, 2018
# 1          Everyone  Art & Design;Pretend Play    January 15, 2018
# 2          Everyone               Art & Design      August 1, 2018
# 3              Teen               Art & Design        June 8, 2018
# 4          Everyone    Art & Design;Creativity       June 20, 2018
# ...             ...                        ...                 ...
# 7718       Everyone                      Tools   December 16, 2017
# 7719       Everyone          Maps & Navigation     August 23, 2016
# 7720       Everyone              Entertainment  September 20, 2014
# 7721       Everyone                    Weather   February 16, 2014
# 7722       Everyone          Books & Reference      March 23, 2014
#
#              Current Ver   Android Ver
# 0                  1.0.0  4.0.3 and up
# 1                  2.0.0  4.0.3 and up
# 2                  1.2.4  4.0.3 and up
# 3     Varies with device    4.2 and up
# 4                    1.1    4.4 and up
# ...                  ...           ...
# 7718                 6.6    2.0 and up
# 7719                 1.3  2.3.3 and up
# 7720                 1.1    1.6 and up
# 7721                 6.0    2.1 and up
# 7722                 0.8    2.2 and up
#
# [7723 rows x 15 columns]

# %%
new_data = new_data[new_data['Reviews'].str.contains('3.0M') == False]
new_data
# Out:
#       level_0  index                                                App  \
# 0           0      0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1      1                                Coloring book moana
# 2           2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3      3                              Sketch - Draw & Paint
# 4           4      4              Pixel Draw - Number Art Coloring Book
# ...       ...    ...                                                ...
# 7718     9286  10732                                 Draw with FP sDraw
# 7719     9301  10755                                     Hondata Mobile
# 7720     9306  10763                                FP Разбитый дисплей
# 7721     9353  10832                                           FR Tides
# 7722     9354  10833                                        Chemin (fr)
#
#                  Category  Rating Reviews   Size     Installs  Type Price  \
# 0          ART_AND_DESIGN     4.1     159  19000      10,000+  Free     0
# 1          ART_AND_DESIGN     3.9     967  14000     500,000+  Free     0
# 2          ART_AND_DESIGN     4.7   87510   8000   5,000,000+  Free     0
# 3          ART_AND_DESIGN     4.5  215644  25000  50,000,000+  Free     0
# 4          ART_AND_DESIGN     4.3     967   2000     100,000+  Free     0
# ...                   ...     ...     ...    ...          ...   ...   ...
# 7718                TOOLS     4.3    3268    467     100,000+  Free     0
# 7719  MAPS_AND_NAVIGATION     4.3     334    676      10,000+  Free     0
# 7720               FAMILY     4.5     922    552      50,000+  Free     0
# 7721              WEATHER     3.8    1195    582     100,000+  Free     0
# 7722  BOOKS_AND_REFERENCE     4.8      44    619       1,000+  Free     0
#
#      Content Rating                     Genres        Last Updated  \
# 0          Everyone               Art & Design     January 7, 2018
# 1          Everyone  Art & Design;Pretend Play    January 15, 2018
# 2          Everyone               Art & Design      August 1, 2018
# 3              Teen               Art & Design        June 8, 2018
# 4          Everyone    Art & Design;Creativity       June 20, 2018
# ...             ...                        ...                 ...
# 7718       Everyone                      Tools   December 16, 2017
# 7719       Everyone          Maps & Navigation     August 23, 2016
# 7720       Everyone              Entertainment  September 20, 2014
# 7721       Everyone                    Weather   February 16, 2014
# 7722       Everyone          Books & Reference      March 23, 2014
#
#              Current Ver   Android Ver
# 0                  1.0.0  4.0.3 and up
# 1                  2.0.0  4.0.3 and up
# 2                  1.2.4  4.0.3 and up
# 3     Varies with device    4.2 and up
# 4                    1.1    4.4 and up
# ...                  ...           ...
# 7718                 6.6    2.0 and up
# 7719                 1.3  2.3.3 and up
# 7720                 1.1    1.6 and up
# 7721                 6.0    2.1 and up
# 7722                 0.8    2.2 and up
#
# [7723 rows x 15 columns]

# %%
new_data.dtypes
# Out:
# level_0             int64
# index               int64
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size                int64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
new_data['Reviews'] = new_data['Reviews'].astype(int)

# %%
new_data.dtypes
# Out:
# level_0             int64
# index               int64
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size                int64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
new_data.columns
# Out:
# Index(['level_0', 'index', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
new_data['Installs'] = new_data['Installs'].map(lambda x:str(x).replace('+',''))
new_data['Installs'] = new_data['Installs'].map(lambda x:str(x).replace(',',''))
new_data['Installs'] = new_data['Installs'].astype(int)

# %%
new_data
# Out:
#       level_0  index                                                App  \
# 0           0      0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1      1                                Coloring book moana
# 2           2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3      3                              Sketch - Draw & Paint
# 4           4      4              Pixel Draw - Number Art Coloring Book
# ...       ...    ...                                                ...
# 7718     9286  10732                                 Draw with FP sDraw
# 7719     9301  10755                                     Hondata Mobile
# 7720     9306  10763                                FP Разбитый дисплей
# 7721     9353  10832                                           FR Tides
# 7722     9354  10833                                        Chemin (fr)
#
#                  Category  Rating  Reviews   Size  Installs  Type Price  \
# 0          ART_AND_DESIGN     4.1      159  19000     10000  Free     0
# 1          ART_AND_DESIGN     3.9      967  14000    500000  Free     0
# 2          ART_AND_DESIGN     4.7    87510   8000   5000000  Free     0
# 3          ART_AND_DESIGN     4.5   215644  25000  50000000  Free     0
# 4          ART_AND_DESIGN     4.3      967   2000    100000  Free     0
# ...                   ...     ...      ...    ...       ...   ...   ...
# 7718                TOOLS     4.3     3268    467    100000  Free     0
# 7719  MAPS_AND_NAVIGATION     4.3      334    676     10000  Free     0
# 7720               FAMILY     4.5      922    552     50000  Free     0
# 7721              WEATHER     3.8     1195    582    100000  Free     0
# 7722  BOOKS_AND_REFERENCE     4.8       44    619      1000  Free     0
#
#      Content Rating                     Genres        Last Updated  \
# 0          Everyone               Art & Design     January 7, 2018
# 1          Everyone  Art & Design;Pretend Play    January 15, 2018
# 2          Everyone               Art & Design      August 1, 2018
# 3              Teen               Art & Design        June 8, 2018
# 4          Everyone    Art & Design;Creativity       June 20, 2018
# ...             ...                        ...                 ...
# 7718       Everyone                      Tools   December 16, 2017
# 7719       Everyone          Maps & Navigation     August 23, 2016
# 7720       Everyone              Entertainment  September 20, 2014
# 7721       Everyone                    Weather   February 16, 2014
# 7722       Everyone          Books & Reference      March 23, 2014
#
#              Current Ver   Android Ver
# 0                  1.0.0  4.0.3 and up
# 1                  2.0.0  4.0.3 and up
# 2                  1.2.4  4.0.3 and up
# 3     Varies with device    4.2 and up
# 4                    1.1    4.4 and up
# ...                  ...           ...
# 7718                 6.6    2.0 and up
# 7719                 1.3  2.3.3 and up
# 7720                 1.1    1.6 and up
# 7721                 6.0    2.1 and up
# 7722                 0.8    2.2 and up
#
# [7723 rows x 15 columns]

# %%
new_data.dtypes
# Out:
# level_0             int64
# index               int64
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size                int64
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
new_data['Price'] = new_data['Price'].map(lambda x:str(x).replace('$',''))
new_data['Price'] = new_data['Price'].astype(float)

# %%
new_data
# Out:
#       level_0  index                                                App  \
# 0           0      0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1      1                                Coloring book moana
# 2           2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3      3                              Sketch - Draw & Paint
# 4           4      4              Pixel Draw - Number Art Coloring Book
# ...       ...    ...                                                ...
# 7718     9286  10732                                 Draw with FP sDraw
# 7719     9301  10755                                     Hondata Mobile
# 7720     9306  10763                                FP Разбитый дисплей
# 7721     9353  10832                                           FR Tides
# 7722     9354  10833                                        Chemin (fr)
#
#                  Category  Rating  Reviews   Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN     4.1      159  19000     10000  Free    0.0
# 1          ART_AND_DESIGN     3.9      967  14000    500000  Free    0.0
# 2          ART_AND_DESIGN     4.7    87510   8000   5000000  Free    0.0
# 3          ART_AND_DESIGN     4.5   215644  25000  50000000  Free    0.0
# 4          ART_AND_DESIGN     4.3      967   2000    100000  Free    0.0
# ...                   ...     ...      ...    ...       ...   ...    ...
# 7718                TOOLS     4.3     3268    467    100000  Free    0.0
# 7719  MAPS_AND_NAVIGATION     4.3      334    676     10000  Free    0.0
# 7720               FAMILY     4.5      922    552     50000  Free    0.0
# 7721              WEATHER     3.8     1195    582    100000  Free    0.0
# 7722  BOOKS_AND_REFERENCE     4.8       44    619      1000  Free    0.0
#
#      Content Rating                     Genres        Last Updated  \
# 0          Everyone               Art & Design     January 7, 2018
# 1          Everyone  Art & Design;Pretend Play    January 15, 2018
# 2          Everyone               Art & Design      August 1, 2018
# 3              Teen               Art & Design        June 8, 2018
# 4          Everyone    Art & Design;Creativity       June 20, 2018
# ...             ...                        ...                 ...
# 7718       Everyone                      Tools   December 16, 2017
# 7719       Everyone          Maps & Navigation     August 23, 2016
# 7720       Everyone              Entertainment  September 20, 2014
# 7721       Everyone                    Weather   February 16, 2014
# 7722       Everyone          Books & Reference      March 23, 2014
#
#              Current Ver   Android Ver
# 0                  1.0.0  4.0.3 and up
# 1                  2.0.0  4.0.3 and up
# 2                  1.2.4  4.0.3 and up
# 3     Varies with device    4.2 and up
# 4                    1.1    4.4 and up
# ...                  ...           ...
# 7718                 6.6    2.0 and up
# 7719                 1.3  2.3.3 and up
# 7720                 1.1    1.6 and up
# 7721                 6.0    2.1 and up
# 7722                 0.8    2.2 and up
#
# [7723 rows x 15 columns]

# %%
new_data.dtypes
# Out:
# level_0             int64
# index               int64
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size                int64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
new_data = new_data[(new_data['Rating'] > 1) & (new_data['Rating'] < 5)]
new_data
# Out:
#       level_0  index                                                App  \
# 0           0      0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1      1                                Coloring book moana
# 2           2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3      3                              Sketch - Draw & Paint
# 4           4      4              Pixel Draw - Number Art Coloring Book
# ...       ...    ...                                                ...
# 7718     9286  10732                                 Draw with FP sDraw
# 7719     9301  10755                                     Hondata Mobile
# 7720     9306  10763                                FP Разбитый дисплей
# 7721     9353  10832                                           FR Tides
# 7722     9354  10833                                        Chemin (fr)
#
#                  Category  Rating  Reviews   Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN     4.1      159  19000     10000  Free    0.0
# 1          ART_AND_DESIGN     3.9      967  14000    500000  Free    0.0
# 2          ART_AND_DESIGN     4.7    87510   8000   5000000  Free    0.0
# 3          ART_AND_DESIGN     4.5   215644  25000  50000000  Free    0.0
# 4          ART_AND_DESIGN     4.3      967   2000    100000  Free    0.0
# ...                   ...     ...      ...    ...       ...   ...    ...
# 7718                TOOLS     4.3     3268    467    100000  Free    0.0
# 7719  MAPS_AND_NAVIGATION     4.3      334    676     10000  Free    0.0
# 7720               FAMILY     4.5      922    552     50000  Free    0.0
# 7721              WEATHER     3.8     1195    582    100000  Free    0.0
# 7722  BOOKS_AND_REFERENCE     4.8       44    619      1000  Free    0.0
#
#      Content Rating                     Genres        Last Updated  \
# 0          Everyone               Art & Design     January 7, 2018
# 1          Everyone  Art & Design;Pretend Play    January 15, 2018
# 2          Everyone               Art & Design      August 1, 2018
# 3              Teen               Art & Design        June 8, 2018
# 4          Everyone    Art & Design;Creativity       June 20, 2018
# ...             ...                        ...                 ...
# 7718       Everyone                      Tools   December 16, 2017
# 7719       Everyone          Maps & Navigation     August 23, 2016
# 7720       Everyone              Entertainment  September 20, 2014
# 7721       Everyone                    Weather   February 16, 2014
# 7722       Everyone          Books & Reference      March 23, 2014
#
#              Current Ver   Android Ver
# 0                  1.0.0  4.0.3 and up
# 1                  2.0.0  4.0.3 and up
# 2                  1.2.4  4.0.3 and up
# 3     Varies with device    4.2 and up
# 4                    1.1    4.4 and up
# ...                  ...           ...
# 7718                 6.6    2.0 and up
# 7719                 1.3  2.3.3 and up
# 7720                 1.1    1.6 and up
# 7721                 6.0    2.1 and up
# 7722                 0.8    2.2 and up
#
# [7438 rows x 15 columns]

# %%
new_data = new_data[(new_data['Installs']) > (new_data['Reviews'])]
new_data = new_data.drop(['level_0','index'], axis = 1)
new_data
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 7718                                 Draw with FP sDraw                TOOLS
# 7719                                     Hondata Mobile  MAPS_AND_NAVIGATION
# 7720                                FP Разбитый дисплей               FAMILY
# 7721                                           FR Tides              WEATHER
# 7722                                        Chemin (fr)  BOOKS_AND_REFERENCE
#
#       Rating  Reviews   Size  Installs  Type  Price Content Rating  \
# 0        4.1      159  19000     10000  Free    0.0       Everyone
# 1        3.9      967  14000    500000  Free    0.0       Everyone
# 2        4.7    87510   8000   5000000  Free    0.0       Everyone
# 3        4.5   215644  25000  50000000  Free    0.0           Teen
# 4        4.3      967   2000    100000  Free    0.0       Everyone
# ...      ...      ...    ...       ...   ...    ...            ...
# 7718     4.3     3268    467    100000  Free    0.0       Everyone
# 7719     4.3      334    676     10000  Free    0.0       Everyone
# 7720     4.5      922    552     50000  Free    0.0       Everyone
# 7721     3.8     1195    582    100000  Free    0.0       Everyone
# 7722     4.8       44    619      1000  Free    0.0       Everyone
#
#                          Genres        Last Updated         Current Ver  \
# 0                  Art & Design     January 7, 2018               1.0.0
# 1     Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2                  Art & Design      August 1, 2018               1.2.4
# 3                  Art & Design        June 8, 2018  Varies with device
# 4       Art & Design;Creativity       June 20, 2018                 1.1
# ...                         ...                 ...                 ...
# 7718                      Tools   December 16, 2017                 6.6
# 7719          Maps & Navigation     August 23, 2016                 1.3
# 7720              Entertainment  September 20, 2014                 1.1
# 7721                    Weather   February 16, 2014                 6.0
# 7722          Books & Reference      March 23, 2014                 0.8
#
#        Android Ver
# 0     4.0.3 and up
# 1     4.0.3 and up
# 2     4.0.3 and up
# 3       4.2 and up
# 4       4.4 and up
# ...            ...
# 7718    2.0 and up
# 7719  2.3.3 and up
# 7720    1.6 and up
# 7721    2.1 and up
# 7722    2.2 and up
#
# [7437 rows x 13 columns]

# %%
new_data_1 = new_data.query('Type=="Free" and Price == 0' )
new_data_2 = new_data.query('Type=="Paid" and Price > 0' )
new_data = pd.concat([new_data_1,new_data_2])
new_data = new_data.reset_index().drop(['index'],axis = 1)
new_data
# Out:
#                                                     App         Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook   ART_AND_DESIGN
# 1                                   Coloring book moana   ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...   ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint   ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book   ART_AND_DESIGN
# ...                                                 ...              ...
# 7432                                   ExDialer PRO Key    COMMUNICATION
# 7433                            Smart Wi-Fi Hotspot PRO    COMMUNICATION
# 7434                     Portable Wi-Fi hotspot Premium    COMMUNICATION
# 7435                            Wi-Fi Rabbit Unlock Key            TOOLS
# 7436                        Circle Colors Pack-FN Theme  PERSONALIZATION
#
#       Rating  Reviews   Size  Installs  Type  Price Content Rating  \
# 0        4.1      159  19000     10000  Free   0.00       Everyone
# 1        3.9      967  14000    500000  Free   0.00       Everyone
# 2        4.7    87510   8000   5000000  Free   0.00       Everyone
# 3        4.5   215644  25000  50000000  Free   0.00           Teen
# 4        4.3      967   2000    100000  Free   0.00       Everyone
# ...      ...      ...    ...       ...   ...    ...            ...
# 7432     4.5     5474     17    100000  Paid   3.99       Everyone
# 7433     3.7      197    957     10000  Paid   2.99       Everyone
# 7434     3.7      481    420     10000  Paid   0.99       Everyone
# 7435     4.5      142     26      5000  Paid   1.00       Everyone
# 7436     4.2        6     89        50  Paid   0.99       Everyone
#
#                          Genres       Last Updated         Current Ver  \
# 0                  Art & Design    January 7, 2018               1.0.0
# 1     Art & Design;Pretend Play   January 15, 2018               2.0.0
# 2                  Art & Design     August 1, 2018               1.2.4
# 3                  Art & Design       June 8, 2018  Varies with device
# 4       Art & Design;Creativity      June 20, 2018                 1.1
# ...                         ...                ...                 ...
# 7432              Communication   January 15, 2014                  81
# 7433              Communication  February 10, 2016                 1.0
# 7434              Communication  December 16, 2015             1.4.0.2
# 7435                      Tools      June 26, 2011               1.0.0
# 7436            Personalization     August 9, 2013                 1.0
#
#        Android Ver
# 0     4.0.3 and up
# 1     4.0.3 and up
# 2     4.0.3 and up
# 3       4.2 and up
# 4       4.4 and up
# ...            ...
# 7432    2.1 and up
# 7433    2.2 and up
# 7434    2.3 and up
# 7435    2.1 and up
# 7436    2.2 and up
#
# [7437 rows x 13 columns]

# %%
plt.boxplot(new_data['Price'])
plt.show()

# %%
plt.boxplot(new_data['Reviews'])
plt.show()

# %%
plt.hist(new_data['Reviews'])
plt.show()

# %%
plt.hist(new_data['Rating'])
plt.title('The Data is skewed on higher side')
plt.show()

# %%
plt.hist(new_data['Size'])
plt.title('The Data is skewed on lower side')
plt.show()

# %%
new_data = new_data[(new_data['Price'] < 200)]
new_data
# Out:
#                                                     App         Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook   ART_AND_DESIGN
# 1                                   Coloring book moana   ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...   ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint   ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book   ART_AND_DESIGN
# ...                                                 ...              ...
# 7432                                   ExDialer PRO Key    COMMUNICATION
# 7433                            Smart Wi-Fi Hotspot PRO    COMMUNICATION
# 7434                     Portable Wi-Fi hotspot Premium    COMMUNICATION
# 7435                            Wi-Fi Rabbit Unlock Key            TOOLS
# 7436                        Circle Colors Pack-FN Theme  PERSONALIZATION
#
#       Rating  Reviews   Size  Installs  Type  Price Content Rating  \
# 0        4.1      159  19000     10000  Free   0.00       Everyone
# 1        3.9      967  14000    500000  Free   0.00       Everyone
# 2        4.7    87510   8000   5000000  Free   0.00       Everyone
# 3        4.5   215644  25000  50000000  Free   0.00           Teen
# 4        4.3      967   2000    100000  Free   0.00       Everyone
# ...      ...      ...    ...       ...   ...    ...            ...
# 7432     4.5     5474     17    100000  Paid   3.99       Everyone
# 7433     3.7      197    957     10000  Paid   2.99       Everyone
# 7434     3.7      481    420     10000  Paid   0.99       Everyone
# 7435     4.5      142     26      5000  Paid   1.00       Everyone
# 7436     4.2        6     89        50  Paid   0.99       Everyone
#
#                          Genres       Last Updated         Current Ver  \
# 0                  Art & Design    January 7, 2018               1.0.0
# 1     Art & Design;Pretend Play   January 15, 2018               2.0.0
# 2                  Art & Design     August 1, 2018               1.2.4
# 3                  Art & Design       June 8, 2018  Varies with device
# 4       Art & Design;Creativity      June 20, 2018                 1.1
# ...                         ...                ...                 ...
# 7432              Communication   January 15, 2014                  81
# 7433              Communication  February 10, 2016                 1.0
# 7434              Communication  December 16, 2015             1.4.0.2
# 7435                      Tools      June 26, 2011               1.0.0
# 7436            Personalization     August 9, 2013                 1.0
#
#        Android Ver
# 0     4.0.3 and up
# 1     4.0.3 and up
# 2     4.0.3 and up
# 3       4.2 and up
# 4       4.4 and up
# ...            ...
# 7432    2.1 and up
# 7433    2.2 and up
# 7434    2.3 and up
# 7435    2.1 and up
# 7436    2.2 and up
#
# [7422 rows x 13 columns]

# %%
new_data = new_data[(new_data['Reviews'] < 2000000)]
new_data
# Out:
#                                                     App         Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook   ART_AND_DESIGN
# 1                                   Coloring book moana   ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...   ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint   ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book   ART_AND_DESIGN
# ...                                                 ...              ...
# 7432                                   ExDialer PRO Key    COMMUNICATION
# 7433                            Smart Wi-Fi Hotspot PRO    COMMUNICATION
# 7434                     Portable Wi-Fi hotspot Premium    COMMUNICATION
# 7435                            Wi-Fi Rabbit Unlock Key            TOOLS
# 7436                        Circle Colors Pack-FN Theme  PERSONALIZATION
#
#       Rating  Reviews   Size  Installs  Type  Price Content Rating  \
# 0        4.1      159  19000     10000  Free   0.00       Everyone
# 1        3.9      967  14000    500000  Free   0.00       Everyone
# 2        4.7    87510   8000   5000000  Free   0.00       Everyone
# 3        4.5   215644  25000  50000000  Free   0.00           Teen
# 4        4.3      967   2000    100000  Free   0.00       Everyone
# ...      ...      ...    ...       ...   ...    ...            ...
# 7432     4.5     5474     17    100000  Paid   3.99       Everyone
# 7433     3.7      197    957     10000  Paid   2.99       Everyone
# 7434     3.7      481    420     10000  Paid   0.99       Everyone
# 7435     4.5      142     26      5000  Paid   1.00       Everyone
# 7436     4.2        6     89        50  Paid   0.99       Everyone
#
#                          Genres       Last Updated         Current Ver  \
# 0                  Art & Design    January 7, 2018               1.0.0
# 1     Art & Design;Pretend Play   January 15, 2018               2.0.0
# 2                  Art & Design     August 1, 2018               1.2.4
# 3                  Art & Design       June 8, 2018  Varies with device
# 4       Art & Design;Creativity      June 20, 2018                 1.1
# ...                         ...                ...                 ...
# 7432              Communication   January 15, 2014                  81
# 7433              Communication  February 10, 2016                 1.0
# 7434              Communication  December 16, 2015             1.4.0.2
# 7435                      Tools      June 26, 2011               1.0.0
# 7436            Personalization     August 9, 2013                 1.0
#
#        Android Ver
# 0     4.0.3 and up
# 1     4.0.3 and up
# 2     4.0.3 and up
# 3       4.2 and up
# 4       4.4 and up
# ...            ...
# 7432    2.1 and up
# 7433    2.2 and up
# 7434    2.3 and up
# 7435    2.1 and up
# 7436    2.2 and up
#
# [7203 rows x 13 columns]

# %%
quartile_10 = np.percentile(new_data['Installs'],10)
quartile_25 = np.percentile(new_data['Installs'],25)
quartile_50 = np.percentile(new_data['Installs'],50)
quartile_70 = np.percentile(new_data['Installs'],70)
quartile_90 = np.percentile(new_data['Installs'],90)
quartile_95 = np.percentile(new_data['Installs'],95)
quartile_99 = np.percentile(new_data['Installs'],99)

# %%
print(quartile_10,quartile_25,quartile_50,quartile_70,quartile_90,quartile_95,quartile_99)
# Out:
# 1000.0 10000.0 100000.0 1000000.0 10000000.0 10000000.0 50000000.0

# %%
plt.boxplot(new_data['Installs'])
plt.show()

# %%
new_data_out = new_data[(new_data['Installs'] > quartile_10) & (new_data['Installs'] < quartile_70)]
new_data_out
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# ...                                              ...             ...     ...
# 7430                         Advanced EX for RENAULT           TOOLS     2.8
# 7432                                ExDialer PRO Key   COMMUNICATION     4.5
# 7433                         Smart Wi-Fi Hotspot PRO   COMMUNICATION     3.7
# 7434                  Portable Wi-Fi hotspot Premium   COMMUNICATION     3.7
# 7435                         Wi-Fi Rabbit Unlock Key           TOOLS     4.5
#
#       Reviews   Size  Installs  Type  Price Content Rating  \
# 0         159  19000     10000  Free   0.00       Everyone
# 1         967  14000    500000  Free   0.00       Everyone
# 4         967   2000    100000  Free   0.00       Everyone
# 5         167   5000     50000  Free   0.00       Everyone
# 6         178  19000     50000  Free   0.00       Everyone
# ...       ...    ...       ...   ...    ...            ...
# 7430      130    143      5000  Paid   4.99       Everyone
# 7432     5474     17    100000  Paid   3.99       Everyone
# 7433      197    957     10000  Paid   2.99       Everyone
# 7434      481    420     10000  Paid   0.99       Everyone
# 7435      142     26      5000  Paid   1.00       Everyone
#
#                          Genres       Last Updated Current Ver   Android Ver
# 0                  Art & Design    January 7, 2018       1.0.0  4.0.3 and up
# 1     Art & Design;Pretend Play   January 15, 2018       2.0.0  4.0.3 and up
# 4       Art & Design;Creativity      June 20, 2018         1.1    4.4 and up
# 5                  Art & Design     March 26, 2017         1.0    2.3 and up
# 6                  Art & Design     April 26, 2018         1.1  4.0.3 and up
# ...                         ...                ...         ...           ...
# 7430                      Tools     March 14, 2015         1.1    1.6 and up
# 7432              Communication   January 15, 2014          81    2.1 and up
# 7433              Communication  February 10, 2016         1.0    2.2 and up
# 7434              Communication  December 16, 2015     1.4.0.2    2.3 and up
# 7435                      Tools      June 26, 2011       1.0.0    2.1 and up
#
# [3336 rows x 13 columns]

# %%
plt.scatter(new_data['Rating'],new_data['Price'])
plt.xlabel('Rating')
plt.ylabel('Price')
plt.show()

# %%
sns.catplot(data = new_data,x = 'Content Rating',y = 'Rating',kind = 'box',palette = 'rocket',height=10,aspect = 0.8)

# %%
# Transforming with log
to_log = ['Reviews','Installs']
df_log = new_data[to_log].applymap(lambda x: np.log(x+1))
df_log
# Out:
#         Reviews   Installs
# 0      5.075174   9.210440
# 1      6.875232  13.122365
# 2     11.379520  15.424949
# 3     12.281389  17.727534
# 4      6.875232  11.512935
# ...         ...        ...
# 7432   8.607948  11.512935
# 7433   5.288267   9.210440
# 7434   6.177944   9.210440
# 7435   4.962845   8.517393
# 7436   1.945910   3.931826
#
# [7203 rows x 2 columns]

# %%
pd.get_dummies(new_data['Content Rating'], prefix=['A'])
# Out:
#       ['A']_Adults only 18+  ['A']_Everyone  ['A']_Everyone 10+  \
# 0                         0               1                   0
# 1                         0               1                   0
# 2                         0               1                   0
# 3                         0               0                   0
# 4                         0               1                   0
# ...                     ...             ...                 ...
# 7432                      0               1                   0
# 7433                      0               1                   0
# 7434                      0               1                   0
# 7435                      0               1                   0
# 7436                      0               1                   0
#
#       ['A']_Mature 17+  ['A']_Teen  ['A']_Unrated
# 0                    0           0              0
# 1                    0           0              0
# 2                    0           0              0
# 3                    0           1              0
# 4                    0           0              0
# ...                ...         ...            ...
# 7432                 0           0              0
# 7433                 0           0              0
# 7434                 0           0              0
# 7435                 0           0              0
# 7436                 0           0              0
#
# [7203 rows x 6 columns]

# %%
new_data['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
new_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# App, Last Updated, Current Ver, and Android Ver are dropped

# %%
# Fit the model step
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)

# %%
y_pred = regressor.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
